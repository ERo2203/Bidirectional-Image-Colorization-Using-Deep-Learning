# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np

input_image = imread("carsgraz_001.bmp")

r,g,b = input_image[:,:,0], input_image[:,:,1], input_image[:,:,2]

gamma = 1.04

r_const, g_const, b_const = 0.2126, 0.7152, 0.0722

grayscale_image = r_const * r ** gamma + g_const * g ** gamma + b_const * b ** gamma

fig = plt.figure(1)
img1,img2 = fig.add_subplot(121), fig.add_subplot(122)

img1.imshow(input_image)
img2.imshow(grayscale_image, cmap=plt.cm.get_cmap('gray'))

fig.show()
plt.show()
# Out:
# C:\Users\91628\AppData\Local\Temp\ipykernel_34604\1756576115.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   img2.imshow(grayscale_image, cmap=plt.cm.get_cmap('gray'))
# C:\Users\91628\AppData\Local\Temp\ipykernel_34604\1756576115.py:21: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
